# %%
# Out:
#   Cell In[6], line 4
#     import global
#            ^
# SyntaxError: invalid syntax

# %%
sk5_14_serial_killers = pd.read_csv('5_to_14_victim_count')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sk5_14_serial_killers = pd.read_xlsx('5_to_14_victim_count.xlsx')
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'

# %%
sk5_14_serial_killers
# Out:
#                     Name                                            Country  \
# 0      Carl Eugene Watts                                      United States
# 1         Philipp Tyurin                                       Soviet Union
# 2    Zdzisław Marchwicki                                             Poland
# 3    Monster of Florence                                              Italy
# 4          Joachim Kroll                                       West Germany
# ..                   ...                                                ...
# 159         Michel Peiry  Switzerland\r\nFrance\r\nUnited States\r\nYugo...
# 160        Hubert Pilčík                                     Czechoslovakia
# 161        Thomas Dillon                                      United States
# 162          Joe Metheny                                      United States
# 163          Sek Kim Wah                                          Singapore
#
# ...

# %%
sk5_14_serial_killers.head(10)
# Out:
#                        Name        Country  Years active Proven victims  \
# 0         Carl Eugene Watts  United States  1974 to 1982             14
# 1            Philipp Tyurin   Soviet Union  1945 to 1946             14
# 2       Zdzisław Marchwicki         Poland  1964 to 1970             14
# 3       Monster of Florence          Italy  1968 to 1985             14
# 4             Joachim Kroll   West Germany  1955 to 1976             14
# 5          Arthur Shawcross  United States  1972 to 1989             14
# 6               The Doodler  United States  1974 to 1975             14
# 7  Marcelo Costa de Andrade         Brazil          1991             14
# 8         Julio Pérez Silva          Chile  1998 to 2001             14
# 9           Sergey Shipilov         Russia  1995 to 1999             14
#
#   Possible victims                                              Notes
# 0              80+  Believed to have killed over 80 women in multi...
# ...

# %%
sk5_14_serial_killers.shape
# Out:
# (164, 6)

# %%
total_killers=sk5_14_serial_killers.groupby('Country')['Proven victims'].sum()

# %%
total_killers
# Out:
# Country
# Argentina                                                                                                                                     1311
# Australia                                                                                                                                  1110876
# Austria\r\nUnited States\r\nCzechoslovakia                                                                                                      11
# Bangladesh                                                                                                                                     117
# Belarus                                                                                                                                          6
# Belgium                                                                                                                                        116
# ...

# %%
top_5=total_killers.sort_values().head(5)

# %%
top_5.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 top_5.plot()
#
# File c:\Users\bmeng\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\bmeng\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...
